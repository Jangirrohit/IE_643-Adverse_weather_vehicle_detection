# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.3.27'

# %%
import torch
torch.__version__
# Out:
# '2.5.0+cu121'

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
from ultralytics import YOLO
model= YOLO('yolov8n.pt')
Results= model.train(data='/content/drive/MyDrive/YOLO/Yolo_annot_dataset/data.yaml', epochs=200, batch=16, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 104MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Resume Training
from ultralytics import YOLO

model= YOLO('/content/drive/MyDrive/YOLO/run/new_run/runs/detect/train/weights/last.pt')
results=model.train(resume=True,time=3)
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/YOLO/run/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/YOLO/Yolo_annot_dataset/data.yaml
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1Yzd9wripneedSFckNAElCWO2IwCCooXs/YOLO/Yolo_annot_dataset/val/labels... 748 images, 0 backgrounds, 0 corrupt: 100% 748/748 [00:10<00:00, 68.69it/s]
# val: New cache created: /content/drive/.shortcut-targets-by-id/1Yzd9wripneedSFckNAElCWO2IwCCooXs/YOLO/Yolo_annot_dataset/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 47/47 [00:16<00:00,  2.86it/s]
#                    all        748       4115      0.863      0.853      0.904      0.674
#                    Car        664       2905      0.925      0.925      0.966      0.805
#                    Van        222        300      0.928      0.943      0.973      0.792
# ...

# %% [markdown]
# Predictions on images

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLO/run/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/YOLO/Yolo_annot_dataset/test
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000000.png: 224x640 2 Cars, 175.4ms
# image 2/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000001.png: 224x640 3 Cars, 8.5ms
# image 3/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000002.png: 224x640 9 Cars, 2 Miscs, 6.7ms
# image 4/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000003.png: 224x640 3 Cars, 1 Van, 6.8ms
# image 5/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000004.png: 224x640 1 Car, 1 Truck, 1 Misc, 8.0ms
# image 6/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000005.png: 224x640 6 Cars, 6.9ms
# image 7/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000006.png: 224x640 3 Cars, 1 Tram, 6.7ms
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model= YOLO('/content/drive/MyDrive/YOLO/runs/detect/train/weights/best.pt')

# predict with the model
results =model('/content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000002.png',  )  #on Image
# results= model('test_videos/vid1.mp4', save=True)  # on videos
# Out:
# image 1/1 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000002.png: 224x640 8 Cars, 2 Miscs, 96.4ms
# Speed: 8.5ms preprocess, 96.4ms inference, 691.9ms postprocess per image at shape (1, 3, 224, 640)
