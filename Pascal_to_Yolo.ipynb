# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import xml.etree.ElementTree as ET

def voc_to_yolo_dir(voc_dir, yolo_dir, class_dict):
    """
    Convert all Pascal VOC annotations in a directory to YOLO format.

    Parameters:
    - voc_dir: Path to the directory containing Pascal VOC XML files
    - yolo_dir: Path to save YOLO annotation files
    - class_dict: Dictionary mapping class names to class IDs
    """
    # Create the YOLO output directory if it doesn't exist
    os.makedirs(yolo_dir, exist_ok=True)

    # Process each XML file in the directory
    for filename in os.listdir(voc_dir):
        if filename.endswith(".xml"):
            voc_path = os.path.join(voc_dir, filename)
            yolo_path = os.path.join(yolo_dir, filename.replace(".xml", ".txt"))

            # Parse the XML file
            tree = ET.parse(voc_path)
            root = tree.getroot()

            # Get image width and height from the XML
            img_width = int(root.find("size/width").text)
            img_height = int(root.find("size/height").text)

            yolo_data = []
            for obj in root.findall('object'):
                class_name = obj.find('name').text
                if class_name not in class_dict:
                    continue

                class_id = class_dict[class_name]
                bndbox = obj.find('bndbox')

                xmin = float(bndbox.find('xmin').text)
                ymin = float(bndbox.find('ymin').text)
                xmax = float(bndbox.find('xmax').text)
                ymax = float(bndbox.find('ymax').text)

                # Calculate YOLO format values
                x_center = ((xmin + xmax) / 2) / img_width
                y_center = ((ymin + ymax) / 2) / img_height
                width = (xmax - xmin) / img_width
                height = (ymax - ymin) / img_height

                yolo_data.append(f"{class_id} {x_center} {y_center} {width} {height}")

            # Save to YOLO annotation file
            with open(yolo_path, "w") as f:
                f.write("\n".join(yolo_data))
            print(f"Converted {filename} to YOLO format.")

# Example usage
class_dict = {
    "car": 0,
    "bus": 1,
    "truck": 2,
    "person": 3,
    "bicycle": 5
}
voc_dir = "/content/drive/MyDrive/YOLO/DAWN/Fog/Fog/Fog_PASCAL_VOC"  # Path to Pascal VOC annotations directory
yolo_dir = "/content/drive/MyDrive/YOLO/DAWN/Fog/Fog/yolo_annotation_my"  # Output path for YOLO annotations

voc_to_yolo_dir(voc_dir, yolo_dir, class_dict)
# Out:
# Converted haze-027.xml to YOLO format.
# Converted haze-026.xml to YOLO format.
# Converted haze-024.xml to YOLO format.
# Converted haze-023.xml to YOLO format.
# Converted haze-022.xml to YOLO format.
# Converted haze-021.xml to YOLO format.
# Converted haze-020.xml to YOLO format.
# Converted haze-019.xml to YOLO format.
# Converted haze-018.xml to YOLO format.
# Converted haze-016.xml to YOLO format.
# Converted haze-013.xml to YOLO format.
# Converted haze-012.xml to YOLO format.
# Converted haze-011.xml to YOLO format.
# Converted foggy-107.xml to YOLO format.
# Converted foggy-106.xml to YOLO format.
# Converted foggy-105.xml to YOLO format.
# Converted foggy-104.xml to YOLO format.
# Converted foggy-103.xml to YOLO format.
# Converted foggy-102.xml to YOLO format.
# Converted foggy-100.xml to YOLO format.
# Converted foggy-099.xml to YOLO format.
# Converted foggy-098.xml to YOLO format.
# Converted foggy-097.xml to YOLO format.
# Converted foggy-096.xml to YOLO format.
# Converted foggy-095.xml to YOLO format.
# Converted foggy-094.xml to YOLO format.
# Converted foggy-093.xml to YOLO format.
# Converted foggy-092.xml to YOLO format.
# Converted foggy-091.xml to YOLO format.
# Converted foggy-090.xml to YOLO format.
# Converted foggy-089.xml to YOLO format.
# Converted foggy-088.xml to YOLO format.
# Converted foggy-087.xml to YOLO format.
# Converted foggy-086.xml to YOLO format.
# Converted foggy-085.xml to YOLO format.
# Converted foggy-084.xml to YOLO format.
# Converted foggy-083.xml to YOLO format.
# Converted foggy-081.xml to YOLO format.
# Converted foggy-080.xml to YOLO format.
# Converted foggy-079.xml to YOLO format.
# Converted foggy-078.xml to YOLO format.
# Converted foggy-077.xml to YOLO format.
# Converted foggy-076.xml to YOLO format.
# Converted foggy-075.xml to YOLO format.
# Converted foggy-074.xml to YOLO format.
# Converted foggy-073.xml to YOLO format.
# Converted foggy-072.xml to YOLO format.
# Converted foggy-070.xml to YOLO format.
# Converted foggy-069.xml to YOLO format.
# Converted foggy-068.xml to YOLO format.
# Converted foggy-067.xml to YOLO format.
# Converted foggy-066.xml to YOLO format.
# Converted foggy-065.xml to YOLO format.
# Converted foggy-064.xml to YOLO format.
# Converted foggy-063.xml to YOLO format.
# Converted foggy-062.xml to YOLO format.
# Converted foggy-061.xml to YOLO format.
# Converted foggy-060.xml to YOLO format.
# Converted foggy-059.xml to YOLO format.
# Converted foggy-058.xml to YOLO format.
# Converted foggy-057.xml to YOLO format.
# Converted foggy-056.xml to YOLO format.
# Converted foggy-055.xml to YOLO format.
# Converted foggy-053.xml to YOLO format.
# Converted foggy-051.xml to YOLO format.
# Converted foggy-050.xml to YOLO format.
# Converted foggy-049.xml to YOLO format.
# Converted foggy-048.xml to YOLO format.
# Converted foggy-047.xml to YOLO format.
# Converted foggy-046.xml to YOLO format.
# Converted foggy-045.xml to YOLO format.
# Converted foggy-044.xml to YOLO format.
# Converted foggy-043.xml to YOLO format.
# Converted foggy-042.xml to YOLO format.
# Converted foggy-041.xml to YOLO format.
# Converted foggy-040.xml to YOLO format.
# Converted foggy-039.xml to YOLO format.
# Converted foggy-038.xml to YOLO format.
# Converted foggy-037.xml to YOLO format.
# Converted foggy-036.xml to YOLO format.
# Converted foggy-035.xml to YOLO format.
# Converted foggy-034.xml to YOLO format.
# Converted foggy-033.xml to YOLO format.
# Converted foggy-031.xml to YOLO format.
# Converted foggy-030.xml to YOLO format.
# Converted foggy-029.xml to YOLO format.
# Converted foggy-028.xml to YOLO format.
# Converted foggy-027.xml to YOLO format.
# Converted foggy-026.xml to YOLO format.
# Converted foggy-025.xml to YOLO format.
# Converted foggy-024.xml to YOLO format.
# Converted foggy-023.xml to YOLO format.
# Converted foggy-022.xml to YOLO format.
# Converted foggy-020.xml to YOLO format.
# Converted foggy-019.xml to YOLO format.
# Converted foggy-018.xml to YOLO format.
# Converted foggy-017.xml to YOLO format.
# Converted foggy-016.xml to YOLO format.
# Converted foggy-015.xml to YOLO format.
# Converted foggy-014.xml to YOLO format.
# Converted mist-966.xml to YOLO format.
# Converted foggy-012.xml to YOLO format.
# Converted foggy-011.xml to YOLO format.
# Converted foggy-010.xml to YOLO format.
# Converted foggy-009.xml to YOLO format.
# Converted foggy-008.xml to YOLO format.
# Converted foggy-007.xml to YOLO format.
# Converted foggy-006.xml to YOLO format.
# Converted foggy-004.xml to YOLO format.
# Converted foggy-003.xml to YOLO format.
# Converted foggy-002.xml to YOLO format.
# Converted foggy-001.xml to YOLO format.
# Converted mist-955.xml to YOLO format.
# Converted mist-938.xml to YOLO format.
# Converted mist-068.xml to YOLO format.
# Converted mist-067.xml to YOLO format.
# Converted mist-064.xml to YOLO format.
# Converted mist-063.xml to YOLO format.
# Converted mist-062.xml to YOLO format.
# Converted mist-061.xml to YOLO format.
# Converted mist-059.xml to YOLO format.
# Converted mist-057.xml to YOLO format.
# Converted mist-053.xml to YOLO format.
# Converted mist-052.xml to YOLO format.
# Converted mist-049.xml to YOLO format.
# Converted mist-048.xml to YOLO format.
# Converted mist-046.xml to YOLO format.
# Converted mist-043.xml to YOLO format.
# Converted mist-015.xml to YOLO format.
# Converted mist-013.xml to YOLO format.
# Converted mist-009.xml to YOLO format.
# Converted mist-003.xml to YOLO format.
# Converted mist-002.xml to YOLO format.
# Converted mist-001.xml to YOLO format.
# Converted haze-150.xml to YOLO format.
# Converted haze-149.xml to YOLO format.
# Converted haze-148.xml to YOLO format.
# Converted haze-145.xml to YOLO format.
# Converted haze-142.xml to YOLO format.
# Converted haze-141.xml to YOLO format.
# Converted haze-139.xml to YOLO format.
# Converted haze-136.xml to YOLO format.
# Converted haze-135.xml to YOLO format.
# Converted haze-134.xml to YOLO format.
# Converted haze-132.xml to YOLO format.
# Converted haze-130.xml to YOLO format.
# Converted haze-129.xml to YOLO format.
# Converted haze-128.xml to YOLO format.
# Converted haze-126.xml to YOLO format.
# Converted haze-124.xml to YOLO format.
# Converted haze-122.xml to YOLO format.
# Converted haze-121.xml to YOLO format.
# Converted haze-120.xml to YOLO format.
# Converted haze-119.xml to YOLO format.
# Converted haze-115.xml to YOLO format.
# Converted haze-112.xml to YOLO format.
# Converted mist-971.xml to YOLO format.
# Converted haze-095.xml to YOLO format.
# Converted haze-094.xml to YOLO format.
# Converted haze-093.xml to YOLO format.
# Converted haze-092.xml to YOLO format.
# Converted haze-091.xml to YOLO format.
# Converted haze-090.xml to YOLO format.
# Converted haze-088.xml to YOLO format.
# Converted haze-087.xml to YOLO format.
# Converted haze-086.xml to YOLO format.
# Converted haze-085.xml to YOLO format.
# Converted haze-084.xml to YOLO format.
# Converted haze-083.xml to YOLO format.
# Converted haze-082.xml to YOLO format.
# Converted haze-081.xml to YOLO format.
# Converted haze-080.xml to YOLO format.
# Converted haze-078.xml to YOLO format.
# Converted haze-077.xml to YOLO format.
# Converted haze-075.xml to YOLO format.
# Converted haze-074.xml to YOLO format.
# Converted haze-072.xml to YOLO format.
# Converted haze-071.xml to YOLO format.
# Converted haze-069.xml to YOLO format.
# Converted haze-068.xml to YOLO format.
# Converted haze-067.xml to YOLO format.
# Converted haze-066.xml to YOLO format.
# Converted haze-065.xml to YOLO format.
# Converted haze-064.xml to YOLO format.
# Converted haze-063.xml to YOLO format.
# Converted haze-061.xml to YOLO format.
# Converted haze-060.xml to YOLO format.
# Converted haze-059.xml to YOLO format.
# Converted haze-058.xml to YOLO format.
# Converted haze-057.xml to YOLO format.
# Converted haze-056.xml to YOLO format.
# Converted haze-054.xml to YOLO format.
# Converted haze-053.xml to YOLO format.
# Converted haze-051.xml to YOLO format.
# Converted haze-050.xml to YOLO format.
# Converted haze-049.xml to YOLO format.
# Converted haze-048.xml to YOLO format.
# Converted haze-046.xml to YOLO format.
# Converted haze-045.xml to YOLO format.
# Converted haze-044.xml to YOLO format.
# Converted haze-043.xml to YOLO format.
# Converted haze-042.xml to YOLO format.
# Converted haze-041.xml to YOLO format.
# Converted haze-040.xml to YOLO format.
# Converted haze-039.xml to YOLO format.
# Converted haze-038.xml to YOLO format.
# Converted haze-037.xml to YOLO format.
# Converted haze-036.xml to YOLO format.
# Converted haze-033.xml to YOLO format.
# Converted haze-032.xml to YOLO format.
# Converted haze-031.xml to YOLO format.
# Converted haze-030.xml to YOLO format.
# Converted haze-029.xml to YOLO format.
# Converted haze-028.xml to YOLO format.
# Converted mist-190.xml to YOLO format.
# Converted mist-189.xml to YOLO format.
# Converted mist-180.xml to YOLO format.
# Converted mist-176.xml to YOLO format.
# Converted mist-168.xml to YOLO format.
# Converted mist-163.xml to YOLO format.
# Converted mist-161.xml to YOLO format.
# Converted mist-158.xml to YOLO format.
# Converted mist-152.xml to YOLO format.
# Converted mist-150.xml to YOLO format.
# Converted mist-149.xml to YOLO format.
# Converted mist-148.xml to YOLO format.
# Converted mist-147.xml to YOLO format.
# Converted mist-145.xml to YOLO format.
# Converted mist-143.xml to YOLO format.
# Converted mist-142.xml to YOLO format.
# Converted mist-141.xml to YOLO format.
# Converted mist-140.xml to YOLO format.
# Converted mist-138.xml to YOLO format.
# Converted mist-137.xml to YOLO format.
# Converted mist-133.xml to YOLO format.
# Converted mist-124.xml to YOLO format.
# Converted mist-123.xml to YOLO format.
# Converted mist-122.xml to YOLO format.
# Converted mist-922.xml to YOLO format.
# Converted mist-121.xml to YOLO format.
# Converted mist-120.xml to YOLO format.
# Converted mist-119.xml to YOLO format.
# Converted mist-117.xml to YOLO format.
# Converted mist-115.xml to YOLO format.
# Converted mist-114.xml to YOLO format.
# Converted mist-111.xml to YOLO format.
# Converted mist-110.xml to YOLO format.
# Converted mist-109.xml to YOLO format.
# Converted mist-105.xml to YOLO format.
# Converted mist-101.xml to YOLO format.
# Converted mist-098.xml to YOLO format.
# Converted mist-088.xml to YOLO format.
# Converted mist-084.xml to YOLO format.
# Converted mist-080.xml to YOLO format.
# Converted mist-075.xml to YOLO format.
# Converted mist-074.xml to YOLO format.
# Converted mist-072.xml to YOLO format.
# Converted mist-071.xml to YOLO format.
# Converted haze-006.xml to YOLO format.
# Converted foggy-108.xml to YOLO format.
# Converted haze-010.xml to YOLO format.
# Converted foggy-112.xml to YOLO format.
# Converted foggy-113.xml to YOLO format.
# Converted haze-002.xml to YOLO format.
# Converted haze-005.xml to YOLO format.
# Converted foggy-111.xml to YOLO format.
# Converted haze-004.xml to YOLO format.
# Converted haze-009.xml to YOLO format.
# Converted foggy-114.xml to YOLO format.
# Converted haze-003.xml to YOLO format.
# Converted haze-007.xml to YOLO format.
# Converted foggy-109.xml to YOLO format.
# Converted haze-096.xml to YOLO format.
# Converted haze-099.xml to YOLO format.
# Converted haze-097.xml to YOLO format.
# Converted haze-102.xml to YOLO format.
# Converted haze-098.xml to YOLO format.
# Converted haze-101.xml to YOLO format.
# Converted haze-106.xml to YOLO format.
# Converted haze-100.xml to YOLO format.
# Converted haze-103.xml to YOLO format.
# Converted mist-019.xml to YOLO format.
# Converted haze-104.xml to YOLO format.
# Converted mist-016.xml to YOLO format.
# Converted haze-111.xml to YOLO format.
# Converted haze-109.xml to YOLO format.
# Converted haze-105.xml to YOLO format.
# Converted haze-110.xml to YOLO format.
# Converted mist-020.xml to YOLO format.
# Converted mist-021.xml to YOLO format.
# Converted mist-023.xml to YOLO format.
# Converted mist-024.xml to YOLO format.
# Converted mist-027.xml to YOLO format.
# Converted mist-030.xml to YOLO format.
# Converted mist-034.xml to YOLO format.
# Converted mist-035.xml to YOLO format.
# Converted mist-033.xml to YOLO format.
# Converted mist-042.xml to YOLO format.
# Converted mist-039.xml to YOLO format.
# Converted mist-041.xml to YOLO format.
