# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/107.7 GB disk)

# %%
from ultralytics import YOLO

# %%
# Load the pre-trained YOLO model
model = YOLO("/content/drive/MyDrive/YOLO/run/runs/detect/train/weights/best.pt")

# %%
print(model)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# Train only some initial few layer and keep other freeze

# %%
for name, param in model.model.named_parameters():

    if any(f"model.{i}." in name for i in range(4)):
        param.requires_grad = True
    else:
        param.requires_grad = False

    # Print for verification (optional)
    print(f"{name}: {'Trainable' if param.requires_grad else 'Frozen'}")
# Out:
# model.0.conv.weight: Trainable
# model.0.bn.weight: Trainable
# model.0.bn.bias: Trainable
# model.1.conv.weight: Trainable
# model.1.bn.weight: Trainable
# model.1.bn.bias: Trainable
# model.2.cv1.conv.weight: Trainable
# model.2.cv1.bn.weight: Trainable
# model.2.cv1.bn.bias: Trainable
# model.2.cv2.conv.weight: Trainable
# model.2.cv2.bn.weight: Trainable
# model.2.cv2.bn.bias: Trainable
# model.2.m.0.cv1.conv.weight: Trainable
# model.2.m.0.cv1.bn.weight: Trainable
# model.2.m.0.cv1.bn.bias: Trainable
# model.2.m.0.cv2.conv.weight: Trainable
# model.2.m.0.cv2.bn.weight: Trainable
# model.2.m.0.cv2.bn.bias: Trainable
# model.3.conv.weight: Trainable
# model.3.bn.weight: Trainable
# model.3.bn.bias: Trainable
# model.4.cv1.conv.weight: Frozen
# model.4.cv1.bn.weight: Frozen
# model.4.cv1.bn.bias: Frozen
# model.4.cv2.conv.weight: Frozen
# model.4.cv2.bn.weight: Frozen
# model.4.cv2.bn.bias: Frozen
# model.4.m.0.cv1.conv.weight: Frozen
# model.4.m.0.cv1.bn.weight: Frozen
# ...

# %%
model.train(
    data='/content/drive/MyDrive/YOLO/Adverse_data_30/data_adv.yaml',
    epochs=50,
    imgsz=640,
    lr0=0.0001

)
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Set the locale to UTF-8
import os
os.environ['LC_ALL'] = 'en_US.UTF-8'
os.environ['LANG'] = 'en_US.UTF-8'

# %% [markdown]
# Validation on adverse weather vehicle images

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/YOLO/Adverse_data_30/data_adv.yaml
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO/Adverse_data_30/val/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:11<00:00,  3.67s/it]
#                    all         40        317      0.573      0.296      0.388      0.262
#                    Car         40        278      0.838      0.637      0.748      0.475
#                    Van          3          4          0          0     0.0763     0.0538
#                  Truck         15         29      0.772      0.379      0.448      0.314
#             Pedestrian          3          6      0.681      0.167      0.279      0.206
# Speed: 8.7ms preprocess, 223.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# ...

# %% [markdown]
# Validation on normal weather vehicle images

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/YOLO/Yolo_annot_dataset/data.yaml
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO/Yolo_annot_dataset/val/labels... 748 images, 0 backgrounds, 0 corrupt: 100% 748/748 [09:04<00:00,  1.37it/s]
# val: New cache created: /content/drive/MyDrive/YOLO/Yolo_annot_dataset/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 47/47 [01:32<00:00,  1.97s/it]
#                    all        748       4115      0.777      0.317      0.402      0.239
#                    Car        664       2905      0.643      0.778      0.777      0.507
#                    Van        222        300      0.698      0.239      0.363      0.235
#                  Truck        115        119      0.264      0.672      0.432       0.29
#             Pedestrian        192        468      0.612      0.499      0.514      0.248
# ...

# %% [markdown]
# Prediction on adverse weather vehicle images

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/YOLO/Adverse_data_30/test/images
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-083.jpg: 416x640 3 Cars, 157.5ms
# image 2/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-084.jpg: 384x640 2 Cars, 170.1ms
# image 3/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-086.jpg: 416x640 4 Cars, 1 Van, 150.6ms
# image 4/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-087.jpg: 480x640 2 Cars, 179.1ms
# image 5/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-088.jpg: 448x640 4 Cars, 161.5ms
# image 6/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-089.jpg: 448x640 3 Cars, 158.6ms
# image 7/25 /content/drive/MyDrive/YOLO/Adverse_data_30/test/images/foggy-090.jpg: 384x640 8 Cars, 1 Truck, 141.4ms
# ...

# %% [markdown]
# Prediction on normal weather vehicle images

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/YOLO/Yolo_annot_dataset/test
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000000.png: 224x640 (no detections), 95.0ms
# image 2/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000001.png: 224x640 3 Cars, 89.6ms
# image 3/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000002.png: 224x640 8 Cars, 80.1ms
# image 4/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000003.png: 224x640 5 Cars, 145.9ms
# image 5/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000004.png: 224x640 1 Truck, 134.6ms
# image 6/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000005.png: 224x640 2 Cars, 81.6ms
# image 7/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000006.png: 224x640 4 Cars, 89.0ms
# image 8/10 /content/drive/MyDrive/YOLO/Yolo_annot_dataset/test/000007.png: 224x640 3 Cars, 93.8ms
# ...
